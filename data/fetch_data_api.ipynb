# %%
# %pip install "kagglehub[pandas-datasets]"
# Out:
# Collecting kagglehub[pandas-datasets]
#   Using cached kagglehub-0.3.13-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: packaging in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from kagglehub[pandas-datasets]) (25.0)
# Requirement already satisfied: pyyaml in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from kagglehub[pandas-datasets]) (6.0.2)
# Requirement already satisfied: requests in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from kagglehub[pandas-datasets]) (2.32.5)
# Requirement already satisfied: tqdm in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from kagglehub[pandas-datasets]) (4.67.1)
# Requirement already satisfied: pandas in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from kagglehub[pandas-datasets]) (2.3.1)
# Requirement already satisfied: numpy>=1.22.4 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from pandas->kagglehub[pandas-datasets]) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from pandas->kagglehub[pandas-datasets]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from pandas->kagglehub[pandas-datasets]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from pandas->kagglehub[pandas-datasets]) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->kagglehub[pandas-datasets]) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from requests->kagglehub[pandas-datasets]) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from requests->kagglehub[pandas-datasets]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from requests->kagglehub[pandas-datasets]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from requests->kagglehub[pandas-datasets]) (2025.8.3)
# Using cached kagglehub-0.3.13-py3-none-any.whl (68 kB)
# Installing collected packages: kagglehub
# Successfully installed kagglehub-0.3.13
# Note: you may need to restart the kernel to use updated packages.

# %%
# Code to fetch dataset from Kaggle API
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = "financial_fraud_detection_dataset.csv"

# Load the latest version
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "aryan208/financial-transactions-dataset-for-fraud-detection",
  file_path,
  # Provide any additional arguments like 
  # sql_query or pandas_kwargs. See the 
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

print("First 5 records:", df.head())
# Out:
# /var/folders/db/1skyxn752xd1wlwnj0dfbqg80000gn/T/ipykernel_17278/3052390108.py:11: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   df = kagglehub.load_dataset(
# First 5 records:   transaction_id                   timestamp sender_account receiver_account  \
# 0        T100000  2023-08-22T09:22:43.516168      ACC877572        ACC388389
# 1        T100001  2023-08-04T01:58:02.606711      ACC895667        ACC944962
# 2        T100002  2023-05-12T11:39:33.742963      ACC733052        ACC377370
# 3        T100003  2023-10-10T06:04:43.195112      ACC996865        ACC344098
# 4        T100004  2023-09-24T08:09:02.700162      ACC584714        ACC497887
#
#     amount transaction_type merchant_category location device_used  is_fraud  \
# 0   343.78       withdrawal         utilities    Tokyo      mobile     False
# 1   419.65       withdrawal            online  Toronto         atm     False
# 2  2773.86          deposit             other   London         pos     False
# 3  1666.22          deposit            online   Sydney         pos     False
# 4    24.43         transfer         utilities  Toronto      mobile     False
#
#   fraud_type  time_since_last_transaction  spending_deviation_score  \
# 0        NaN                          NaN                     -0.21
# 1        NaN                          NaN                     -0.14
# 2        NaN                          NaN                     -1.78
# 3        NaN                          NaN                     -0.60
# 4        NaN                          NaN                      0.79
#
#    velocity_score  geo_anomaly_score payment_channel       ip_address  \
# 0               3               0.22            card   13.101.214.112
# 1               7               0.96             ACH    172.52.47.194
# 2              20               0.89            card     185.98.35.23
# 3               6               0.37   wire_transfer    107.136.36.87
# 4              13               0.27             ACH  108.161.108.255
#
#   device_hash
# 0    D8536477
# 1    D2622631
# 2    D4823498
# 3    D9961380
# 4    D7637601

# %%
# Create working copy of original dataset

fraud_dataset=df.copy()

print(fraud_dataset.head())
# Out:
#   transaction_id                   timestamp sender_account receiver_account  \
# 0        T100000  2023-08-22T09:22:43.516168      ACC877572        ACC388389
# 1        T100001  2023-08-04T01:58:02.606711      ACC895667        ACC944962
# 2        T100002  2023-05-12T11:39:33.742963      ACC733052        ACC377370
# 3        T100003  2023-10-10T06:04:43.195112      ACC996865        ACC344098
# 4        T100004  2023-09-24T08:09:02.700162      ACC584714        ACC497887
#
#     amount transaction_type merchant_category location device_used  is_fraud  \
# 0   343.78       withdrawal         utilities    Tokyo      mobile     False
# 1   419.65       withdrawal            online  Toronto         atm     False
# 2  2773.86          deposit             other   London         pos     False
# 3  1666.22          deposit            online   Sydney         pos     False
# 4    24.43         transfer         utilities  Toronto      mobile     False
#
#   fraud_type  time_since_last_transaction  spending_deviation_score  \
# 0        NaN                          NaN                     -0.21
# 1        NaN                          NaN                     -0.14
# 2        NaN                          NaN                     -1.78
# 3        NaN                          NaN                     -0.60
# 4        NaN                          NaN                      0.79
#
#    velocity_score  geo_anomaly_score payment_channel       ip_address  \
# 0               3               0.22            card   13.101.214.112
# 1               7               0.96             ACH    172.52.47.194
# 2              20               0.89            card     185.98.35.23
# 3               6               0.37   wire_transfer    107.136.36.87
# 4              13               0.27             ACH  108.161.108.255
#
#   device_hash
# 0    D8536477
# 1    D2622631
# 2    D4823498
# 3    D9961380
# 4    D7637601

# %%
import kagglehub

path = kagglehub.dataset_path("aryan208/financial-transactions-dataset-for-fraud-detection")
print(path)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 3
#       1 import kagglehub
# ----> 3 path = kagglehub.dataset_path("aryan208/financial-transactions-dataset-for-fraud-detection")
#       4 print(path)
#
# AttributeError: module 'kagglehub' has no attribute 'dataset_path'
